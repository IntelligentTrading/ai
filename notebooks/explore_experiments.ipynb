# %%
import numpy as np 
from matplotlib import pyplot as plt
# %matplotlib notebook

import sys
sys.path.append("..")
sys.path.append("../src/")

# %%
from src.vizualization.plotting import plot_model_results, plot_3class_colored_prediction
from src.data.data_sources import get_combined_cleaned_onecoin_df
from src.data.datasets import get_dataset_manycoins_fused
from src.models.keras_models import build_lstm_model, Metrics
from train import rnn_1_train_basic
# Out:
# /Users/alex/anaconda3/envs/py3.6_ITT/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# /Users/alex/anaconda3/envs/py3.6_ITT/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# # Browse Commands:
#        run all
#        compare all
#        display 1
#      show 0     show the results
#      view full           View all columns (the default view)
#      delete 4.1          Delete record 1 of experiment 4
#      delete unfinished   Delete all experiment records that have not run to completion
#      delete 4-6          Delete all records from experiments 4, 5, 6.  You will be asked to confirm the deletion.

# %%
rnn_1_train_basic.browse(close_after=True)
# Out:
# =================================================================================== Experiments ==================================================================================
# |   # | Start Time       | Duration   | Status          | Args Changed?   | Result                                                                                               |
# ...
# 0  rnn_1_train_basic                                                                                                                                                             |
# |   0 | Aug 08, 20:39:24 | 1:25:30    | Ran Succesfully | <No Change>     | ({val_loss:[0.7281277558822067,0.7053814747900056,0.7212309396808363],val_acc:[0.8192201309033058... |
# ...
# Enter command or experiment # to run (h for help) >> show 0
#     Plot training progress of loss and accuracy:
#     Final Scores (plot_model_results):
#      f1       :[array([0.899,   nan,   nan]), array([0.9, nan, nan]), array([0.898,   nan,   nan])]
# ...

# %% [markdown]
# # Explore records

# %%
variants = rnn_1_train_basic.get_all_variants()
print(variants[0])

records = variants[0].get_records()
print(records)
# Out:
# Experiment rnn_1_train_basic
# ...

# %%
records[0].get_result()
# Out:
# ({'acc': [0.5593014833225332, 0.5641829118470945, 0.5640254464126349],
#   'loss': [1.008692449407683, 0.9838237874966601, 0.9824172107342851],
#   'val_acc': [0.8192201309033058, 0.8192201309033058, 0.8192201309033058],
#   'val_loss': [0.7281277558822067, 0.7053814747900056, 0.7212309396808363]},
#  {'f1': [array([0.899,   nan,   nan]),
#    array([0.9, nan, nan]),
#    array([0.898,   nan,   nan])],
#   'precision': [array([0.82,  nan,  nan]),
#    array([0.82,  nan,  nan]),
#    array([0.82,  nan,  nan])],
#   'recall': [array([0.994, 0.   , 0.   ]),
#    array([0.997, 0.   , 0.   ]),
#    array([0.993, 0.   , 0.   ])]},
#  {'future': 24,
#   'point': 2000,
#   'price': array([1.579e+12, 1.568e+12, 1.590e+12, ..., 6.933e+11, 6.934e+11,
#          6.941e+11]),
#   'win_size': 288,
#   'y_predicted': array([[0.586, 0.207, 0.207],
#          [0.584, 0.208, 0.208],
#          [0.583, 0.208, 0.208],
#          ...,
#          [0.596, 0.2  , 0.204],
#          [0.588, 0.204, 0.208],
# ...

# %%
records[0].get_log()
# Out:
# 'Train on 63506 samples, validate on 11207 samples\nEpoch 1/3\n - 2634s - loss: 1.0087 - acc: 0.5593 - val_loss: 0.7281 - val_acc: 0.8192\n/Users/alex/Projects_pycharm/ITT/ittai/src/models/keras_models.py:26: RuntimeWarning: invalid value encountered in true_divide\n  precision = tp/(tp+fp)\n      > valid_f1: [0.899   nan   nan];   valid_precision: [0.82  nan  nan] ;   valid_recall: [0.994 0.    0.   ]\nEpoch 2/3\n - 263s - loss: 0.9838 - acc: 0.5642 - val_loss: 0.7054 - val_acc: 0.8192\n      > valid_f1: [0.9 nan nan];   valid_precision: [0.82  nan  nan] ;   valid_recall: [0.997 0.    0.   ]\nEpoch 3/3\n - 268s - loss: 0.9824 - acc: 0.5640 - val_loss: 0.7212 - val_acc: 0.8192\n      > valid_f1: [0.898   nan   nan];   valid_precision: [0.82  nan  nan] ;   valid_recall: [0.993 0.    0.   ]\n'
