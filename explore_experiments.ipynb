# %%
import numpy as np 
from matplotlib import pyplot as plt
# %matplotlib notebook

from train import single_train, add_all_experiments_variants

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
add_all_experiments_variants()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-e9e2510544d4> in <module>()
# ----> 1 add_all_experiments_variants()
#
# /Users/alex/PycharmProjects/ITT/ittai/train.py in add_all_experiments_variants()
#     132         lr=0.0005,
#     133         batch_size=batch_size,
# --> 134         epochs=epochs
#     135     )
#     136
#
# /Users/alex/anaconda3/anaconda/envs/py3.6.ITT/lib/python3.6/site-packages/artemis/experiments/experiments.py in add_variant(self, variant_name, **kwargs)
#     156         :return: The experiment.
#     157         """
# --> 158         return self._create_experiment_variant(() if variant_name is None else (variant_name, ), kwargs, is_root=False)
#     159
#     160     def copy_variants(self, other_experiment):
#
# /Users/alex/anaconda3/anaconda/envs/py3.6.ITT/lib/python3.6/site-packages/artemis/experiments/experiments.py in _create_experiment_variant(self, args, kwargs, is_root)
#     125         name = args[0] if len(args) == 1 else _kwargs_to_experiment_name(kwargs)
#     126         assert isinstance(name, str), 'Name should be a string.  Not: {}'.format(name)
# --> 127         assert name not in self.variants, 'Variant "%s" already exists.' % (name,)
#     128         ex = Experiment(
#     129             name=self.name + '.' + name,
#
# AssertionError: Variant "batch_size=512,data_dim=4,epochs=1,future=24,label_func=label_3class_return_target,lr=0.0005,num_classes=3,res_period=10min,return_target=0.008,win_size=288" already exists.

# %%
single_train.browse(close_after=True)
# Out:
# =================================================================================== Experiments ==================================================================================
# |   # | Start Time       | Duration   | Status          | Args Changed?   | Result                                                                                               |
# ==================================================================================================================================================================================
# 0  single_train                                                                                                                                                                  |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1  single_train.batch_size=512,data_dim=4,epochs=1,future=24,label_func=label_3class_return_target,lr=0.0005,num_classes=3,res_period=10min,return_target=0.008,win_size=288     |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2  single_train.batch_size=512,data_dim=4,epochs=1,future=24,label_func=label_3class_return_target,lr=0.007,num_classes=3,res_period=10min,return_target=0.008,win_size=288      |
# |   0 | Jun 23, 15:35:31 | 0:15:21    | Ran Succesfully | <No Change>     | ({val_loss:[1.01549795413],val_acc:[0.645434185681],loss:[1.08992489836],acc:[0.375998946203]},{f... |
# |   1 | Jun 23, 18:15:36 | 0:11:19    | Ran Succesfully | <No Change>     | ({val_loss:[1.04196801412],val_acc:[0.560836030999],loss:[1.09099083407],acc:[0.370115043607]},{f... |
# ==================================================================================================================================================================================
# Enter command or experiment # to run (h for help) >> show 2.1
# <img src="data:image/png;base64,..." width="800">
#     FInal Scores:
#      f1       :[array([ 0.10887097,  0.        ,  0.        ])]
#      recall   :[array([ 0.05821056,  0.        ,  0.        ])]
#      precision:[array([ 0.83937824,  0.        ,  0.        ])]
# <img src="data:image/png;base64,..." width="1200">
